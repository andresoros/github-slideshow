# %% [markdown]
# $$\mathbb{E}[X] = \sum_{i}x_iP(x)=\frac{x_n + x_1}{2}.$$
# Reemplazamos el valor de la funcion de probabilidad de la variable aleatoria discreta uniforme
# $$= \sum_{i=1}^{n}x_1\frac{1}{n}$$
#
# Al tener una constante por propiedades de la sumatoria podemos sacarla de esta
# $$= \frac{1}{n} \sum_{i=1}^{n}x_i$$
#
# Por definicion tenemos
# $$\sum_{i=1}^{n}x_i = \frac{n(x_1+x_2)}{2}$$
#
# Sustituyendo
# $$\  \frac{1}{n} \sum_{i=1}^{n}x_i = \frac{1}{n}\left(\frac{n(x_1+x_n)}{2}\right)$$
#
# Desarrollando
# $$ = \frac{1}{n}\left(\frac{n(x_1+x_n)}{2}\right) = \frac{n(x_1+x_n)}{2n}$$
#
# $$ = \frac{x_1+x_n}{2}$$
